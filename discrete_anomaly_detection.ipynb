# %% [markdown]
# # Lesson

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import env
import seaborn as sns

# %%
def parse_log_entry(entry):
    parts = entry.split()
    output = {}
    output['ip'] = parts[0]
    output['timestamp'] = parts[3][1:].replace(':', ' ', 1)
    output['request_method'] = parts[5][1:]
    output['request_path'] = parts[6]
    output['http_version'] = parts[7][:-1]
    output['status_code'] = parts[8]
    output['size'] = int(parts[9])
    output['user_agent'] = ' '.join(parts[11:]).replace('"', '')
    return pd.Series(output)

url = f'mysql+pymysql://{env.user}:{env.password}@{env.host}/logs'   
df = pd.read_sql('SELECT * FROM api_access', url)
# df = pd.concat([df.entry, df.entry.apply(parse_log_entry)], axis=1)
df = df.entry.apply(parse_log_entry)

# %%
df
# Out:
#                  ip             timestamp request_method  \
# 0      97.105.19.58  16/Apr/2019 19:34:42            GET
# 1      97.105.19.58  16/Apr/2019 19:34:42            GET
# 2      97.105.19.58  16/Apr/2019 19:34:44            GET
# 3      97.105.19.58  16/Apr/2019 19:34:46            GET
# 4      97.105.19.58  16/Apr/2019 19:34:48            GET
# ...             ...                   ...            ...
# 13969  97.105.19.58  17/Apr/2019 12:55:12            GET
# 13970  97.105.19.58  17/Apr/2019 12:55:12            GET
# 13971  97.105.19.58  17/Apr/2019 12:55:13            GET
# 13972  97.105.19.58  17/Apr/2019 12:55:13            GET
# 13973  97.105.19.58  17/Apr/2019 12:55:14            GET
#
#                 request_path http_version status_code    size  \
# 0      /api/v1/sales?page=81     HTTP/1.1         200  512495
# 1              /api/v1/items     HTTP/1.1         200    3561
# 2      /api/v1/sales?page=82     HTTP/1.1         200  510103
# 3      /api/v1/sales?page=83     HTTP/1.1         200  510003
# 4      /api/v1/sales?page=84     HTTP/1.1         200  511963
# ...                      ...          ...         ...     ...
# 13969  /api/v1/sales?page=62     HTTP/1.1         200  511544
# 13970  /api/v1/sales?page=65     HTTP/1.1         200  511201
# 13971  /api/v1/sales?page=73     HTTP/1.1         200  511781
# 13972  /api/v1/sales?page=69     HTTP/1.1         200  510136
# 13973  /api/v1/sales?page=71     HTTP/1.1         200  510166
#
#                    user_agent
# 0      python-requests/2.21.0
# 1      python-requests/2.21.0
# 2      python-requests/2.21.0
# 3      python-requests/2.21.0
# 4      python-requests/2.21.0
# ...                       ...
# 13969  python-requests/2.21.0
# 13970  python-requests/2.21.0
# 13971  python-requests/2.21.0
# 13972  python-requests/2.21.0
# 13973  python-requests/2.21.0
#
# [13974 rows x 8 columns]

# %%
new = pd.DataFrame([
    ["95.31.18.119", "21/Apr/2019 10:02:41", "GET", "/api/v1/items/", "HTTP/1.1", '200', 1153005, "python-requests/2.21.0"],
    ["95.31.16.121", "17/Apr/2019 19:36:41", "GET", "/api/v1/sales?page=79/", "HTTP/1.1", '301', 1005, "python-requests/2.21.0"],
    ["97.105.15.120", "18/Apr/2019 19:42:41", "GET", "/api/v1/sales?page=79/", "HTTP/1.1", '301', 2560, "python-requests/2.21.0"],
    ["97.105.19.58", "19/Apr/2019 19:42:41", "GET", "/api/v1/sales?page=79/", "HTTP/1.1", '200', 2056327, "python-requests/2.21.0"],
], columns=df.columns)

df = pd.concat([df,new])

# %%
df['size_mb'] = df['size'] / 1024 / 1024
df.timestamp = pd.to_datetime(df.timestamp)
df = df.set_index('timestamp')

# %%
def value_counts_and_frequencies(s: pd.Series, dropna=True) -> pd.DataFrame:
    return pd.merge(
        s.value_counts(dropna=False).rename('count'),
        s.value_counts(dropna=False, normalize=True).rename('proba'),
        left_index=True,
        right_index=True,
    )

# %%
ip_df = value_counts_and_frequencies(df.ip)
ip_df.head()
# Out:
#                 count     proba
# ip
# 97.105.19.58    11999  0.858420
# 173.173.113.51   1059  0.075762
# 72.181.113.170    613  0.043855
# 72.181.105.81     246  0.017599
# 68.201.219.223     21  0.001502

# %%
status_given_ip = (
    df.groupby('ip')
    .status_code.value_counts(normalize=True)
    .rename('proba_status_given_ip')
    .reset_index()
)
status_given_ip.head()
# Out:
#                ip status_code  proba_status_given_ip
# 0  173.173.113.51         200                    1.0
# 1     24.26.242.9         200                    1.0
# 2    3.88.129.158         200                    1.0
# 3    3.92.201.136         200                    1.0
# 4   34.207.64.242         200                    1.0

# %%
status_given_ip[status_given_ip.status_code != '200']
# Out:
#                 ip status_code  proba_status_given_ip
# 18  72.181.113.170         499               0.003263
# 19    95.31.16.121         301               1.000000
# 21   97.105.15.120         301               1.000000
# 23    97.105.19.58         499               0.001167

# %%
df[df.ip == '173.173.113.51'].head(1)
# Out:
#                                  ip request_method   request_path  \
# timestamp
# 2019-04-17 01:31:30  173.173.113.51            GET  /api/v1/sales
#
#                     http_version status_code    size              user_agent  \
# timestamp
# 2019-04-17 01:31:30     HTTP/1.1         200  493905  python-requests/2.21.0
#
#                       size_mb
# timestamp
# 2019-04-17 01:31:30  0.471025

# %%
df[df.ip == '24.26.242.9'].head(1)
# Out:
#                               ip request_method          request_path  \
# timestamp
# 2019-04-17 05:50:21  24.26.242.9            GET  /api/v1/items?page=1
#
#                     http_version status_code  size              user_agent  \
# timestamp
# 2019-04-17 05:50:21     HTTP/1.1         200  3561  python-requests/2.21.0
#
#                       size_mb
# timestamp
# 2019-04-17 05:50:21  0.003396

# %%
df[df.ip == '95.31.16.121']
# Out:
#                                ip request_method            request_path  \
# timestamp
# 2019-04-17 19:36:41  95.31.16.121            GET  /api/v1/sales?page=79/
#
#                     http_version status_code  size              user_agent  \
# timestamp
# 2019-04-17 19:36:41     HTTP/1.1         301  1005  python-requests/2.21.0
#
#                       size_mb
# timestamp
# 2019-04-17 19:36:41  0.000958

# %%
df[df.ip == '97.105.15.120']
# Out:
#                                 ip request_method            request_path  \
# timestamp
# 2019-04-18 19:42:41  97.105.15.120            GET  /api/v1/sales?page=79/
#
#                     http_version status_code  size              user_agent  \
# timestamp
# 2019-04-18 19:42:41     HTTP/1.1         301  2560  python-requests/2.21.0
#
#                       size_mb
# timestamp
# 2019-04-18 19:42:41  0.002441

# %%
status_given_ip[status_given_ip.proba_status_given_ip < 1]
# Out:
#                 ip status_code  proba_status_given_ip
# 17  72.181.113.170         200               0.996737
# 18  72.181.113.170         499               0.003263
# 22    97.105.19.58         200               0.998833
# 23    97.105.19.58         499               0.001167

# %% [markdown]
# # Exercises

# %%
df
# Out:
#                                 ip request_method            request_path  \
# timestamp
# 2019-04-16 19:34:42   97.105.19.58            GET   /api/v1/sales?page=81
# 2019-04-16 19:34:42   97.105.19.58            GET           /api/v1/items
# 2019-04-16 19:34:44   97.105.19.58            GET   /api/v1/sales?page=82
# 2019-04-16 19:34:46   97.105.19.58            GET   /api/v1/sales?page=83
# 2019-04-16 19:34:48   97.105.19.58            GET   /api/v1/sales?page=84
# ...                            ...            ...                     ...
# 2019-04-17 12:55:14   97.105.19.58            GET   /api/v1/sales?page=71
# 2019-04-21 10:02:41   95.31.18.119            GET          /api/v1/items/
# 2019-04-17 19:36:41   95.31.16.121            GET  /api/v1/sales?page=79/
# 2019-04-18 19:42:41  97.105.15.120            GET  /api/v1/sales?page=79/
# 2019-04-19 19:42:41   97.105.19.58            GET  /api/v1/sales?page=79/
#
#                     http_version status_code     size              user_agent  \
# timestamp
# 2019-04-16 19:34:42     HTTP/1.1         200   512495  python-requests/2.21.0
# 2019-04-16 19:34:42     HTTP/1.1         200     3561  python-requests/2.21.0
# 2019-04-16 19:34:44     HTTP/1.1         200   510103  python-requests/2.21.0
# 2019-04-16 19:34:46     HTTP/1.1         200   510003  python-requests/2.21.0
# 2019-04-16 19:34:48     HTTP/1.1         200   511963  python-requests/2.21.0
# ...                          ...         ...      ...                     ...
# 2019-04-17 12:55:14     HTTP/1.1         200   510166  python-requests/2.21.0
# 2019-04-21 10:02:41     HTTP/1.1         200  1153005  python-requests/2.21.0
# 2019-04-17 19:36:41     HTTP/1.1         301     1005  python-requests/2.21.0
# 2019-04-18 19:42:41     HTTP/1.1         301     2560  python-requests/2.21.0
# 2019-04-19 19:42:41     HTTP/1.1         200  2056327  python-requests/2.21.0
#
#                       size_mb
# timestamp
# 2019-04-16 19:34:42  0.488753
# 2019-04-16 19:34:42  0.003396
# 2019-04-16 19:34:44  0.486472
# 2019-04-16 19:34:46  0.486377
# 2019-04-16 19:34:48  0.488246
# ...                       ...
# 2019-04-17 12:55:14  0.486532
# 2019-04-21 10:02:41  1.099591
# 2019-04-17 19:36:41  0.000958
# 2019-04-18 19:42:41  0.002441
# 2019-04-19 19:42:41  1.961066
#
# [13978 rows x 8 columns]

# %%
df.columns[1:]
# Out:
# Index(['request_method', 'request_path', 'http_version', 'status_code', 'size',
#        'user_agent', 'size_mb'],
#       dtype='object')

# %%
rp = value_counts_and_frequencies(df.request_path)
http = value_counts_and_frequencies(df.http_version)
status = value_counts_and_frequencies(df.status_code)
user = value_counts_and_frequencies(df.user_agent)

# %% [markdown]
# ## Request Path

# %%
rp
# Out:
#                                  count     proba
# request_path
# /api/v1/sales?page=2               709  0.050723
# /api/v1/items                      464  0.033195
# /api/v1/items?page=2               291  0.020818
# /api/v1/items?page=3               219  0.015667
# /api/v1/stores                     162  0.011590
# ...                                ...       ...
# /api/v1                              1  0.000072
# /api/v1//api/v1/items/next_page      1  0.000072
# /api/v1//api/v1/items                1  0.000072
# /api/v1/items?page=0                 1  0.000072
# /api/V1/HiZach!                      1  0.000072
#
# [220 rows x 2 columns]

# %% [markdown]
# ## Http Version

# %%
http
# Out:
#               count  proba
# http_version
# HTTP/1.1      13978    1.0

# %% [markdown]
# ### No anomalies are present here

# %% [markdown]
# ## Status Code

# %%
status
# Out:
#              count     proba
# status_code
# 200          13960  0.998712
# 499             16  0.001145
# 301              2  0.000143

# %% [markdown]
# ### Like we spoke about during the lesson, we have a few status code anomalies here so let's take a look at them.

# %% [markdown]
# ### First, let's look at 499

# %%
df[df['status_code'] == '499']
# Out:
#                                  ip request_method            request_path  \
# timestamp
# 2019-04-16 19:55:15    97.105.19.58            GET    /api/v1/sales?page=2
# 2019-04-16 19:56:02    97.105.19.58            GET   /api/v1/sales?page=21
# 2019-04-16 20:28:46    97.105.19.58            GET    /api/v1/sales?page=2
# 2019-04-16 20:33:24    97.105.19.58            GET   /api/v1/sales?page=29
# 2019-04-16 20:38:13    97.105.19.58            GET           /api/v1/items
# 2019-04-16 20:38:55    97.105.19.58            GET           /api/v1/items
# 2019-04-16 20:39:00    97.105.19.58            GET           /api/v1/items
# 2019-04-16 20:45:17    97.105.19.58            GET           /api/v1/items
# 2019-04-16 20:45:28    97.105.19.58            GET    /api/v1/sales?page=2
# 2019-04-16 21:00:35    97.105.19.58            GET  /api/v1/sales?page=115
# 2019-04-16 21:02:07    97.105.19.58            GET   /api/v1/sales?page=47
# 2019-04-16 21:30:46    97.105.19.58            GET   /api/v1/sales?page=25
# 2019-04-16 21:39:21    97.105.19.58            GET   /api/v1/sales?page=80
# 2019-04-16 22:21:38    97.105.19.58            GET   /api/v1/sales?page=69
# 2019-04-17 02:48:36  72.181.113.170            GET    /api/v1/sales?page=8
# 2019-04-17 03:42:44  72.181.113.170            GET  /api/v1/sales?page=133
#
#                     http_version status_code  size              user_agent  \
# timestamp
# 2019-04-16 19:55:15     HTTP/1.1         499     0  python-requests/2.20.1
# 2019-04-16 19:56:02     HTTP/1.1         499     0  python-requests/2.20.1
# 2019-04-16 20:28:46     HTTP/1.1         499     0  python-requests/2.21.0
# 2019-04-16 20:33:24     HTTP/1.1         499     0  python-requests/2.21.0
# 2019-04-16 20:38:13     HTTP/1.1         499     0  python-requests/2.21.0
# 2019-04-16 20:38:55     HTTP/1.1         499     0  python-requests/2.21.0
# 2019-04-16 20:39:00     HTTP/1.1         499     0  python-requests/2.21.0
# 2019-04-16 20:45:17     HTTP/1.1         499     0  python-requests/2.21.0
# 2019-04-16 20:45:28     HTTP/1.1         499     0  python-requests/2.21.0
# 2019-04-16 21:00:35     HTTP/1.1         499     0  python-requests/2.20.1
# 2019-04-16 21:02:07     HTTP/1.1         499     0  python-requests/2.20.1
# 2019-04-16 21:30:46     HTTP/1.1         499     0  python-requests/2.21.0
# 2019-04-16 21:39:21     HTTP/1.1         499     0  python-requests/2.21.0
# 2019-04-16 22:21:38     HTTP/1.1         499     0  python-requests/2.21.0
# 2019-04-17 02:48:36     HTTP/1.1         499     0  python-requests/2.21.0
# 2019-04-17 03:42:44     HTTP/1.1         499     0  python-requests/2.21.0
#
#                      size_mb
# timestamp
# 2019-04-16 19:55:15      0.0
# 2019-04-16 19:56:02      0.0
# 2019-04-16 20:28:46      0.0
# 2019-04-16 20:33:24      0.0
# 2019-04-16 20:38:13      0.0
# 2019-04-16 20:38:55      0.0
# 2019-04-16 20:39:00      0.0
# 2019-04-16 20:45:17      0.0
# 2019-04-16 20:45:28      0.0
# 2019-04-16 21:00:35      0.0
# 2019-04-16 21:02:07      0.0
# 2019-04-16 21:30:46      0.0
# 2019-04-16 21:39:21      0.0
# 2019-04-16 22:21:38      0.0
# 2019-04-17 02:48:36      0.0
# 2019-04-17 03:42:44      0.0

# %% [markdown]
# ### Of the 16 cases present, 14 belong to the same IP address (i believe this to be codeup, although the times appear to be pretty late in the day)
# ### There also appears to be similar times present here, all between the hours of 8 PM to 4 AM

# %% [markdown]
# ### Let's look at just that ip for the bottom two and see if we can find anything new about these outliers

# %%
df[df.ip == '72.181.113.170']
# Out:
#                                  ip request_method            request_path  \
# timestamp
# 2019-04-17 02:12:07  72.181.113.170            GET           /api/v1/items
# 2019-04-17 02:18:07  72.181.113.170            GET                       /
# 2019-04-17 02:18:07  72.181.113.170            GET            /favicon.ico
# 2019-04-17 02:48:27  72.181.113.170            GET           /api/v1/sales
# 2019-04-17 02:48:28  72.181.113.170            GET    /api/v1/sales?page=2
# ...                             ...            ...                     ...
# 2019-04-17 03:52:00  72.181.113.170            GET  /api/v1/sales?page=179
# 2019-04-17 03:52:02  72.181.113.170            GET  /api/v1/sales?page=180
# 2019-04-17 03:52:04  72.181.113.170            GET  /api/v1/sales?page=181
# 2019-04-17 03:52:06  72.181.113.170            GET  /api/v1/sales?page=182
# 2019-04-17 03:52:08  72.181.113.170            GET  /api/v1/sales?page=183
#
#                     http_version status_code    size  \
# timestamp
# 2019-04-17 02:12:07     HTTP/1.1         200    3561
# 2019-04-17 02:18:07     HTTP/1.1         200      42
# 2019-04-17 02:18:07     HTTP/1.1         200     162
# 2019-04-17 02:48:27     HTTP/1.1         200  493905
# 2019-04-17 02:48:28     HTTP/1.1         200  494819
# ...                          ...         ...     ...
# 2019-04-17 03:52:00     HTTP/1.1         200  511963
# 2019-04-17 03:52:02     HTTP/1.1         200  510788
# 2019-04-17 03:52:04     HTTP/1.1         200  510317
# 2019-04-17 03:52:06     HTTP/1.1         200  510540
# 2019-04-17 03:52:08     HTTP/1.1         200  308243
#
#                                                             user_agent  \
# timestamp
# 2019-04-17 02:12:07                             python-requests/2.21.0
# 2019-04-17 02:18:07  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3...
# 2019-04-17 02:18:07  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3...
# 2019-04-17 02:48:27                             python-requests/2.21.0
# 2019-04-17 02:48:28                             python-requests/2.21.0
# ...                                                                ...
# 2019-04-17 03:52:00                             python-requests/2.21.0
# 2019-04-17 03:52:02                             python-requests/2.21.0
# 2019-04-17 03:52:04                             python-requests/2.21.0
# 2019-04-17 03:52:06                             python-requests/2.21.0
# 2019-04-17 03:52:08                             python-requests/2.21.0
#
#                       size_mb
# timestamp
# 2019-04-17 02:12:07  0.003396
# 2019-04-17 02:18:07  0.000040
# 2019-04-17 02:18:07  0.000154
# 2019-04-17 02:48:27  0.471025
# 2019-04-17 02:48:28  0.471896
# ...                       ...
# 2019-04-17 03:52:00  0.488246
# 2019-04-17 03:52:02  0.487125
# 2019-04-17 03:52:04  0.486676
# 2019-04-17 03:52:06  0.486889
# 2019-04-17 03:52:08  0.293963
#
# [613 rows x 8 columns]

# %% [markdown]
# #### We have quite a few hits coming from this ip address, all between 2 and 4 AM on April 17th
# #### This definitely strikes me as odd. The speed of the requests also stands out to me, whether it's just a resourceful student who made a nice API gathering function, or something altogether odd has yet to be seen.
# #### I'd definitely like to explore this occurence more to determine if malicious intent is present.

# %% [markdown]
# ### First I'd like to see if hitting the server between 2 and 4 am is normal, maybe this cohort was overnight?

# %%
df
# Out:
#                                 ip request_method            request_path  \
# timestamp
# 2019-04-16 19:34:42   97.105.19.58            GET   /api/v1/sales?page=81
# 2019-04-16 19:34:42   97.105.19.58            GET           /api/v1/items
# 2019-04-16 19:34:44   97.105.19.58            GET   /api/v1/sales?page=82
# 2019-04-16 19:34:46   97.105.19.58            GET   /api/v1/sales?page=83
# 2019-04-16 19:34:48   97.105.19.58            GET   /api/v1/sales?page=84
# ...                            ...            ...                     ...
# 2019-04-17 12:55:14   97.105.19.58            GET   /api/v1/sales?page=71
# 2019-04-21 10:02:41   95.31.18.119            GET          /api/v1/items/
# 2019-04-17 19:36:41   95.31.16.121            GET  /api/v1/sales?page=79/
# 2019-04-18 19:42:41  97.105.15.120            GET  /api/v1/sales?page=79/
# 2019-04-19 19:42:41   97.105.19.58            GET  /api/v1/sales?page=79/
#
#                     http_version status_code     size              user_agent  \
# timestamp
# 2019-04-16 19:34:42     HTTP/1.1         200   512495  python-requests/2.21.0
# 2019-04-16 19:34:42     HTTP/1.1         200     3561  python-requests/2.21.0
# 2019-04-16 19:34:44     HTTP/1.1         200   510103  python-requests/2.21.0
# 2019-04-16 19:34:46     HTTP/1.1         200   510003  python-requests/2.21.0
# 2019-04-16 19:34:48     HTTP/1.1         200   511963  python-requests/2.21.0
# ...                          ...         ...      ...                     ...
# 2019-04-17 12:55:14     HTTP/1.1         200   510166  python-requests/2.21.0
# 2019-04-21 10:02:41     HTTP/1.1         200  1153005  python-requests/2.21.0
# 2019-04-17 19:36:41     HTTP/1.1         301     1005  python-requests/2.21.0
# 2019-04-18 19:42:41     HTTP/1.1         301     2560  python-requests/2.21.0
# 2019-04-19 19:42:41     HTTP/1.1         200  2056327  python-requests/2.21.0
#
#                       size_mb
# timestamp
# 2019-04-16 19:34:42  0.488753
# 2019-04-16 19:34:42  0.003396
# 2019-04-16 19:34:44  0.486472
# 2019-04-16 19:34:46  0.486377
# 2019-04-16 19:34:48  0.488246
# ...                       ...
# 2019-04-17 12:55:14  0.486532
# 2019-04-21 10:02:41  1.099591
# 2019-04-17 19:36:41  0.000958
# 2019-04-18 19:42:41  0.002441
# 2019-04-19 19:42:41  1.961066
#
# [13978 rows x 8 columns]

# %%
df.index
# Out:
# DatetimeIndex(['2019-04-16 19:34:42', '2019-04-16 19:34:42',
#                '2019-04-16 19:34:44', '2019-04-16 19:34:46',
#                '2019-04-16 19:34:48', '2019-04-16 19:34:48',
#                '2019-04-16 19:34:50', '2019-04-16 19:34:52',
#                '2019-04-16 19:34:52', '2019-04-16 19:34:53',
#                ...
#                '2019-04-17 12:55:09', '2019-04-17 12:55:12',
#                '2019-04-17 12:55:12', '2019-04-17 12:55:13',
#                '2019-04-17 12:55:13', '2019-04-17 12:55:14',
#                '2019-04-21 10:02:41', '2019-04-17 19:36:41',
#                '2019-04-18 19:42:41', '2019-04-19 19:42:41'],
#               dtype='datetime64[ns]', name='timestamp', length=13978, freq=None)

# %% [markdown]
# ### Now let's take a look at the 301 status code

# %%
df[df['status_code'] == '301']
# Out:
#                                 ip request_method            request_path  \
# timestamp
# 2019-04-17 19:36:41   95.31.16.121            GET  /api/v1/sales?page=79/
# 2019-04-18 19:42:41  97.105.15.120            GET  /api/v1/sales?page=79/
#
#                     http_version status_code  size              user_agent  \
# timestamp
# 2019-04-17 19:36:41     HTTP/1.1         301  1005  python-requests/2.21.0
# 2019-04-18 19:42:41     HTTP/1.1         301  2560  python-requests/2.21.0
#
#                       size_mb
# timestamp
# 2019-04-17 19:36:41  0.000958
# 2019-04-18 19:42:41  0.002441

# %% [markdown]
# ### Both the server errors occured requesting the same page, I want to see if any attempts succeed at pulling this page

# %%
df[df.request_path == '/api/v1/sales?page=79/']
# Out:
#                                 ip request_method            request_path  \
# timestamp
# 2019-04-17 19:36:41   95.31.16.121            GET  /api/v1/sales?page=79/
# 2019-04-18 19:42:41  97.105.15.120            GET  /api/v1/sales?page=79/
# 2019-04-19 19:42:41   97.105.19.58            GET  /api/v1/sales?page=79/
#
#                     http_version status_code     size              user_agent  \
# timestamp
# 2019-04-17 19:36:41     HTTP/1.1         301     1005  python-requests/2.21.0
# 2019-04-18 19:42:41     HTTP/1.1         301     2560  python-requests/2.21.0
# 2019-04-19 19:42:41     HTTP/1.1         200  2056327  python-requests/2.21.0
#
#                       size_mb
# timestamp
# 2019-04-17 19:36:41  0.000958
# 2019-04-18 19:42:41  0.002441
# 2019-04-19 19:42:41  1.961066

# %% [markdown]
# ### One did get through but it was the latest date and was the codeup IP address.
# #### Two immediate assumptions present themselves:
# - having a codeup ip allowed access to content
# - the server wasn't responsive until April 19th

# %% [markdown]
# ## User

# %%
user
# Out:
#                                                     count     proba
# user_agent
# python-requests/2.21.0                              12005  0.858850
# python-requests/2.20.1                               1911  0.136715
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4)...     34  0.002432
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; r...      8  0.000572
# Slackbot-LinkExpanding 1.0 (+https://api.slack....      7  0.000501
# Slackbot 1.0 (+https://api.slack.com/robots)            6  0.000429
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3)...      4  0.000286
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3)...      2  0.000143
# Python-urllib/3.7                                       1  0.000072

# %%
odd_user = df[(df.user_agent != 'python-requests/2.21.0') & 
              (df.user_agent != 'python-requests/2.20.1') & 
              (df.user_agent != 'Slackbot-LinkExpanding 1.0 (+https://api.slack.com/robots)') & 
              (df.user_agent != 'Slackbot 1.0 (+https://api.slack.com/robots)') &
              (df.ip != '97.105.19.58')]
odd_user
# Out:
#                                  ip request_method          request_path  \
# timestamp
# 2019-04-16 22:01:52   72.181.105.81            GET         /api/v1/items
# 2019-04-16 22:01:52   72.181.105.81            GET          /favicon.ico
# 2019-04-16 22:01:53   72.181.105.81            GET              /api/v1/
# 2019-04-16 22:01:53   72.181.105.81            GET          /favicon.ico
# 2019-04-16 22:02:42   72.181.105.81            GET              /api/v1/
# 2019-04-16 22:02:42   72.181.105.81            GET          /favicon.ico
# 2019-04-16 23:44:34   72.181.105.81            GET                     /
# 2019-04-16 23:44:35   72.181.105.81            GET          /favicon.ico
# 2019-04-17 01:25:07   72.181.105.81            GET                     /
# 2019-04-17 01:25:07   70.121.214.34            GET                     /
# 2019-04-17 01:25:07   70.121.214.34            GET          /favicon.ico
# 2019-04-17 01:25:21   72.181.105.81            GET        /documentation
# 2019-04-17 01:33:06   72.181.105.81            GET  /api/v1/items?page=2
# 2019-04-17 01:33:19   72.181.105.81            GET  /api/v1/items?page=3
# 2019-04-17 01:33:32   72.181.105.81            GET  /api/v1/items?page=4
# 2019-04-17 01:56:33   72.181.105.81            GET        /api/v1/stores
# 2019-04-17 01:56:57   72.181.105.81            GET         /api/v1/sales
# 2019-04-17 02:07:44   72.181.105.81            GET         /api/v1/sales
# 2019-04-17 02:18:07  72.181.113.170            GET                     /
# 2019-04-17 02:18:07  72.181.113.170            GET          /favicon.ico
#
#                     http_version status_code    size  \
# timestamp
# 2019-04-16 22:01:52     HTTP/1.1         200    3561
# 2019-04-16 22:01:52     HTTP/1.1         200     162
# 2019-04-16 22:01:53     HTTP/1.1         200     162
# 2019-04-16 22:01:53     HTTP/1.1         200     162
# 2019-04-16 22:02:42     HTTP/1.1         200     162
# 2019-04-16 22:02:42     HTTP/1.1         200     162
# 2019-04-16 23:44:34     HTTP/1.1         200      42
# 2019-04-16 23:44:35     HTTP/1.1         200     162
# 2019-04-17 01:25:07     HTTP/1.1         200      42
# 2019-04-17 01:25:07     HTTP/1.1         200      42
# 2019-04-17 01:25:07     HTTP/1.1         200     162
# 2019-04-17 01:25:21     HTTP/1.1         200     348
# 2019-04-17 01:33:06     HTTP/1.1         200    3659
# 2019-04-17 01:33:19     HTTP/1.1         200    1787
# 2019-04-17 01:33:32     HTTP/1.1         200      48
# 2019-04-17 01:56:33     HTTP/1.1         200    1328
# 2019-04-17 01:56:57     HTTP/1.1         200  493905
# 2019-04-17 02:07:44     HTTP/1.1         200  493905
# 2019-04-17 02:18:07     HTTP/1.1         200      42
# 2019-04-17 02:18:07     HTTP/1.1         200     162
#
#                                                             user_agent  \
# timestamp
# 2019-04-16 22:01:52  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 22:01:52  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 22:01:53  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 22:01:53  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 22:02:42  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 22:02:42  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 23:44:34  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-16 23:44:35  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4...
# 2019-04-17 01:25:07  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...
# 2019-04-17 01:25:07  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3...
# 2019-04-17 01:25:07  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3...
# 2019-04-17 01:25:21  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...
# 2019-04-17 01:33:06  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...
# 2019-04-17 01:33:19  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...
# 2019-04-17 01:33:32  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...
# 2019-04-17 01:56:33  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...
# 2019-04-17 01:56:57  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...
# 2019-04-17 02:07:44  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; ...
# 2019-04-17 02:18:07  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3...
# 2019-04-17 02:18:07  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3...
#
#                       size_mb
# timestamp
# 2019-04-16 22:01:52  0.003396
# 2019-04-16 22:01:52  0.000154
# 2019-04-16 22:01:53  0.000154
# 2019-04-16 22:01:53  0.000154
# 2019-04-16 22:02:42  0.000154
# 2019-04-16 22:02:42  0.000154
# 2019-04-16 23:44:34  0.000040
# 2019-04-16 23:44:35  0.000154
# 2019-04-17 01:25:07  0.000040
# 2019-04-17 01:25:07  0.000040
# 2019-04-17 01:25:07  0.000154
# 2019-04-17 01:25:21  0.000332
# 2019-04-17 01:33:06  0.003489
# 2019-04-17 01:33:19  0.001704
# 2019-04-17 01:33:32  0.000046
# 2019-04-17 01:56:33  0.001266
# 2019-04-17 01:56:57  0.471025
# 2019-04-17 02:07:44  0.471025
# 2019-04-17 02:18:07  0.000040
# 2019-04-17 02:18:07  0.000154
